# %%
import sqlite3
con = sqlite3.connect('db.sqlite')
cur = con.cursor()
table_list = [a for a in cur.execute("SELECT name FROM sqlite_master WHERE type = 'table'")]
print(table_list)
cur.execute("SELECT * FROM records")
a = cur.execute("SELECT * FROM records")
for x in a:
    print(x)
# Out:
# [('records',)]
# ('STORAGE_VERSION_RECORD_ID', 'StorageVersionRecord', '{"metadata":{},"id":"STORAGE_VERSION_RECORD_ID","createdAt":"2024-08-15T16:09:27.115Z","storageVersion":"0.5","updatedAt":"2024-08-16T17:53:06.974Z"}', '{}')
# ('MEDIATOR_ROUTING_RECORD', 'MediatorRoutingRecord', '{"_tags":{"created_at":"2024-08-15T16:10:55.875Z","updated_at":"2024-08-15T16:10:55.876Z"},"metadata":{},"id":"MEDIATOR_ROUTING_RECORD","createdAt":"2024-08-15T16:10:55.875Z","routingKeys":["6vEKmjqR5RdTic98BsJoXXKosWD5Vqu7DykXSkKEFuZ4"],"updatedAt":"2024-08-15T16:10:55.876Z"}', '{}')
# ('a2401fdb-315d-4d8b-ab6f-39ada0253809', 'OutOfBandRecord', '{"metadata":{},"id":"a2401fdb-315d-4d8b-ab6f-39ada0253809","createdAt":"2024-08-15T16:11:51.535Z","outOfBandInvitation":{"@type":"https://didcomm.org/out-of-band/1.1/invitation","@id":"7364b03d-10dc-4bcf-83f1-8dc29b07f106","label":"agentKasra1","accept":["didcomm/aip1","didcomm/aip2;env=rfc19"],"handshake_protocols":["https://didcomm.org/didexchange/1.1","https://didcomm.org/connections/1.0"],"services":[{"id":"#inline-0","serviceEndpoint":"http://192.168.2.109:3001","type":"did-communication","recipientKeys":["did:key:z6Mks4S4j6bm9b3nNcTjhXqLWmBH8AX3F5vKQdqUgreQi5DA"],"routingKeys":[]}]},"role":"sender","state":"done","autoAcceptConnection":true,"reusable":false,"updatedAt":"2024-08-15T16:12:12.331Z"}', '{"recipientKeyFingerprints":["z6Mks4S4j6bm9b3nNcTjhXqLWmBH8AX3F5vKQdqUgreQi5DA"],"role":"sender","state":"done","invitationId":"7364b03d-10dc-4bcf-83f1-8dc29b07f106","threadId":"7364b03d-10dc-4bcf-83f1-8dc29b07f106"}')
# ('d1373001-a957-40cf-964c-d5a89c393d21', 'DidRecord', '{"_tags":{"recipientKeyFingerprints":["z6MkgJXCt5gESUDEZwwK25oVQVVA3iSqAZSFBKyWqfoUDbe1"],"role":"received","method":"peer","did":"did:peer:1zQmaTeY9YSVcopb63DSLWKG8xTCCPZpbJ9mg1Dv1Q7A1RGE","methodSpecificIdentifier":"1zQmaTeY9YSVcopb63DSLWKG8xTCCPZpbJ9mg1Dv1Q7A1RGE","created_at":"2024-08-15T16:12:11.760Z","updated_at":"2024-08-15T16:12:11.761Z"},"metadata":{},"id":"d1373001-a957-40cf-964c-d5a89c393d21","did":"did:peer:1zQmaTeY9YSVcopb63DSLWKG8xTCCPZpbJ9mg1Dv1Q7A1RGE","role":"received","didDocument":{"@context":["https://w3id.org/did/v1"],"id":"did:peer:1zQmaTeY9YSVcopb63DSLWKG8xTCCPZpbJ9mg1Dv1Q7A1RGE","service":[{"id":"#inline-0","serviceEndpoint":"https://mediator.digicred.services:3002","type":"did-communication","priority":0,"recipientKeys":["#key-1"],"routingKeys":["did:key:z6MkiAGAFumGbXRwNPA4paPEnCvBUS8C4yG65Kb1ig8GYX9S#z6MkiAGAFumGbXRwNPA4paPEnCvBUS8C4yG65Kb1ig8GYX9S"]}],"authentication":[{"id":"#key-1","type":"Ed25519VerificationKey2018","controller":"#id","publicKeyBase58":"2rGAHqRo6vimTT6cLWqeZPwAE9AykgBtVK4b1PqTJNrd"}],"keyAgreement":[{"id":"#key-2","type":"X25519KeyAgreementKey2019","controller":"#id","publicKeyBase58":"7Ls3sbuDspvFbwgA2oww5UaeMdKpk3AMPnTQki4o6Yc"}]},"createdAt":"2024-08-15T16:12:11.760Z","updatedAt":"2024-08-15T16:12:11.761Z"}', '{"recipientKeyFingerprints":["z6MkgJXCt5gESUDEZwwK25oVQVVA3iSqAZSFBKyWqfoUDbe1"],"role":"received","method":"peer","did":"did:peer:1zQmaTeY9YSVcopb63DSLWKG8xTCCPZpbJ9mg1Dv1Q7A1RGE","methodSpecificIdentifier":"1zQmaTeY9YSVcopb63DSLWKG8xTCCPZpbJ9mg1Dv1Q7A1RGE"}')
# ('a20fa9e7-aa22-4a3c-a16e-33001770d770', 'ConnectionRecord', '{"metadata":{},"connectionTypes":[],"previousDids":[],"previousTheirDids":[],"id":"a20fa9e7-aa22-4a3c-a16e-33001770d770","createdAt":"2024-08-15T16:12:11.763Z","did":"did:peer:1zQme6CSQmKxZpLYhzW4jomHLDdxZTUo8QYxEFCZopJa4WMT","theirDid":"did:peer:1zQmaTeY9YSVcopb63DSLWKG8xTCCPZpbJ9mg1Dv1Q7A1RGE","theirLabel":"DigiCred Wallet","state":"completed","role":"responder","autoAcceptConnection":true,"threadId":"9d78fc44-ffab-43dc-b8eb-1a66d50623e8","protocol":"https://didcomm.org/didexchange/1.x","outOfBandId":"a2401fdb-315d-4d8b-ab6f-39ada0253809","updatedAt":"2024-08-15T16:12:12.333Z"}', '{"state":"completed","role":"responder","threadId":"9d78fc44-ffab-43dc-b8eb-1a66d50623e8","did":"did:peer:1zQme6CSQmKxZpLYhzW4jomHLDdxZTUo8QYxEFCZopJa4WMT","theirDid":"did:peer:1zQmaTeY9YSVcopb63DSLWKG8xTCCPZpbJ9mg1Dv1Q7A1RGE","outOfBandId":"a2401fdb-315d-4d8b-ab6f-39ada0253809","connectionTypes":[],"previousDids":[],"previousTheirDids":[],"created_at":"2024-08-15T16:12:11.763Z","updated_at":"2024-08-15T16:12:11.763Z"}')
# ('6bff4f8a-2ebd-4a36-be4a-af08a5b31022', 'DidRecord', '{"_tags":{"recipientKeyFingerprints":["z6Mks4S4j6bm9b3nNcTjhXqLWmBH8AX3F5vKQdqUgreQi5DA"],"role":"created","method":"peer","did":"did:peer:1zQme6CSQmKxZpLYhzW4jomHLDdxZTUo8QYxEFCZopJa4WMT","methodSpecificIdentifier":"1zQme6CSQmKxZpLYhzW4jomHLDdxZTUo8QYxEFCZopJa4WMT","created_at":"2024-08-15T16:12:11.782Z","updated_at":"2024-08-15T16:12:11.782Z"},"metadata":{},"id":"6bff4f8a-2ebd-4a36-be4a-af08a5b31022","did":"did:peer:1zQme6CSQmKxZpLYhzW4jomHLDdxZTUo8QYxEFCZopJa4WMT","role":"created","didDocument":{"@context":["https://w3id.org/did/v1"],"id":"did:peer:1zQme6CSQmKxZpLYhzW4jomHLDdxZTUo8QYxEFCZopJa4WMT","service":[{"id":"#inline-0","serviceEndpoint":"http://192.168.2.109:3001","type":"did-communication","priority":0,"recipientKeys":["#key-1"],"routingKeys":[]}],"authentication":[{"id":"#key-1","type":"Ed25519VerificationKey2018","controller":"#id","publicKeyBase58":"DcB28rMKp3ZKG7d31xsVffdHJbFBqCfxicvYragPnrRn"}],"keyAgreement":[{"id":"#key-2","type":"X25519KeyAgreementKey2019","controller":"#id","publicKeyBase58":"4bejhce35mtqRmDCPMbRwCkszBTMSRjdWRG7Fd8YPTk6"}]},"createdAt":"2024-08-15T16:12:11.782Z","updatedAt":"2024-08-15T16:12:11.782Z"}', '{"recipientKeyFingerprints":["z6Mks4S4j6bm9b3nNcTjhXqLWmBH8AX3F5vKQdqUgreQi5DA"],"role":"created","method":"peer","did":"did:peer:1zQme6CSQmKxZpLYhzW4jomHLDdxZTUo8QYxEFCZopJa4WMT","methodSpecificIdentifier":"1zQme6CSQmKxZpLYhzW4jomHLDdxZTUo8QYxEFCZopJa4WMT"}')
# ('caaa125e-068b-4249-85d6-af8434e81237', 'OutOfBandRecord', '{"metadata":{"_internal/legacyInvitation":{"legacyInvitationType":"connections/1.x"}},"id":"caaa125e-068b-4249-85d6-af8434e81237","createdAt":"2024-08-15T16:12:21.633Z","outOfBandInvitation":{"@type":"https://didcomm.org/out-of-band/1.1/invitation","@id":"d37378db-fd37-4fd6-b55a-4420a109ec91","label":"agentKasra1","accept":["didcomm/aip1","didcomm/aip2;env=rfc19"],"handshake_protocols":["https://didcomm.org/connections/1.0"],"services":[{"id":"#inline-0","serviceEndpoint":"http://192.168.2.109:3001","type":"did-communication","recipientKeys":["did:key:z6MkfAkhvR8PAC4KZfsHv875jVmYdzTtLKYDbBQqukvp1Tki"],"routingKeys":[]}]},"role":"sender","state":"await-response","autoAcceptConnection":true,"reusable":false,"updatedAt":"2024-08-15T16:12:21.637Z"}', '{"recipientKeyFingerprints":["z6MkfAkhvR8PAC4KZfsHv875jVmYdzTtLKYDbBQqukvp1Tki"],"role":"sender","state":"await-response","invitationId":"d37378db-fd37-4fd6-b55a-4420a109ec91","threadId":"d37378db-fd37-4fd6-b55a-4420a109ec91","created_at":"2024-08-15T16:12:21.633Z","updated_at":"2024-08-15T16:12:21.634Z"}')

# %%
import sqlite3

con = sqlite3.connect('db.sqlite') # the name of the sqlite file
cur = con.cursor()
table_list = [a for a in cur.execute("SELECT name FROM sqlite_master WHERE type = 'table'")]
print(table_list)
import json
jj = "listConnection.json" # the json file
_json = json.load(open(jj))
results = _json["results"]
for result in results:
    connectionId = result["connection_id"]
    createdAt = result["created_at"]
    updatedAt = result["updated_at"]
    state = result["rfc23_state"]
    try:
        theirDid = result["their_did"]
    except:
        theirDid = ""
    try:
        myDid = result["my_did"]
    except:
        myDid = ""
    try:
        theirRole = result["their_role"]
    except:
        theirRole = ""
    try:
        theirDid = result["their_did"]
    except:
        theirDid = ""
    try:
        theirLabel = result["their_label"]
    except:
        theirLabel = ""
    try:
        alias = result["alias"]
    except:
        alias = ""
    value = {
            "metadata": {},
            "connectionTypes": [],
            "previousDids": [],
            "previousTheirDids": [],
            "id": connectionId,
            "createdAt": createdAt,
            "did": myDid,
            "theirDid": theirDid,
            "theirLabel": theirLabel,
            "state": state,
            "role": theirRole,
            "autoAcceptConnection": True,
            "threadId": "",
            "protocol": "https://didcomm.org/didexchange/1.x",
            "outOfBandId": "",
            "updatedAt": updatedAt,
            }
    tags = {
            "state": state,
            "role": theirRole,
            "threadId": "",
            "did": myDid,
            "theirDid": theirDid,
            "outOfBandId": "",
            "connectionTypes": [],
            "previousDids": [],
            "previousTheirDids": [],
            "created_at": createdAt,
            "updated_at": updatedAt
            }
    cur.execute("INSERT INTO records (id, type, value, tags) VALUES (?, ?, ?, ?)", (connectionId,'ConnectionRecord', json.dumps(value), json.dumps(tags)))
    con.commit()
# Out:
# [('records',)]

# %%
import sqlite3
from datetime import datetime
con = sqlite3.connect('db.sqlite') # the name of the sqlite file
cur = con.cursor()
table_list = [a for a in cur.execute("SELECT name FROM sqlite_master WHERE type = 'table'")]
print(table_list)
import json
jj = "resolved_dids.json" # the json file
_json = json.load(open(jj))
results = _json
current_time = datetime.utcnow().strftime('%Y-%m-%dT%H:%M:%S.%f')[:-3] + 'Z'
for result in results:
    tags = {
        "recipientKeyFingerprints":[],
        "role":"received",
        "method":result["did_document"]["id"].split(":")[1],
        "did":result["did_document"]["id"],
        "methodSpecificIdentifier":result["did_document"]["id"].split(":")[-1]
    }
    value = {
        "_tags":{
            "recipientKeyFingerprints":[],
            "role":"received",
            "method":result["did_document"]["id"].split(":")[1],
            "did":result["did_document"]["id"],
            "methodSpecificIdentifier":result["did_document"]["id"].split(":")[-1],
            "created_at":current_time,
            "updated_at":current_time
        },
        "metadata":result["metadata"],
        "id":result["id"],
        "did":result["did_document"]["id"],
        "role":"received",
        "didDocument": {
            "@context":result["did_document"]["@context"],
            "id":result["did_document"]["id"],
            "service":result["did_document"]["service"],
            "authentication":result["did_document"]["verificationMethod"],
            "keyAgreement":[]
        },
        "createdAt":current_time,
        "updatedAt":current_time
    }
    connectionId = result["id"]
    import uuid;
    
    cur.execute("INSERT INTO records (id, type, value, tags) VALUES (?, ?, ?, ?)", (str(uuid.uuid1()),'DidRecord', json.dumps(value), json.dumps(tags)))
    con.commit()
# Out:
# [('records',)]
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[3], line 46
#      44 connectionId = result["id"]
#      45 import uuid;
# ---> 46 cur.execute("INSERT INTO records (id, type, value, tags) VALUES (?, ?, ?, ?)", (connectionId,'DidRecord', json.dumps(value), json.dumps(tags)))
#      47 con.commit()
#
# OperationalError: database is locked
